# %% [markdown]
# # Departamento de vendas
# - Base de dados: https://www.kaggle.com/c/rossmann-store-sales/data

# %% [markdown]
# ## Importação das bibliotecas e base de dados

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# ### Dados de vendas

# %%
stateholiday = {'a': 'feriado público', 'b': 'páscoa', 'c': 'natal', '0': 'nenhum'}

# %%
sales_train_df = pd.read_csv('/content/train.csv')
sales_train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
sales_train_df.head()
# Out:
#    Store  DayOfWeek        Date  Sales  ...  Open  Promo  StateHoliday SchoolHoliday
# 0      1          5  2015-07-31   5263  ...     1      1             0             1
# 1      2          5  2015-07-31   6064  ...     1      1             0             1
# 2      3          5  2015-07-31   8314  ...     1      1             0             1
# 3      4          5  2015-07-31  13995  ...     1      1             0             1
# 4      5          5  2015-07-31   4822  ...     1      1             0             1
#
# [5 rows x 9 columns]

# %%
sales_train_df.describe()
# Out:
#               Store     DayOfWeek  ...         Promo  SchoolHoliday
# count  1.017209e+06  1.017209e+06  ...  1.017209e+06   1.017209e+06
# mean   5.584297e+02  3.998341e+00  ...  3.815145e-01   1.786467e-01
# std    3.219087e+02  1.997391e+00  ...  4.857586e-01   3.830564e-01
# min    1.000000e+00  1.000000e+00  ...  0.000000e+00   0.000000e+00
# 25%    2.800000e+02  2.000000e+00  ...  0.000000e+00   0.000000e+00
# 50%    5.580000e+02  4.000000e+00  ...  0.000000e+00   0.000000e+00
# 75%    8.380000e+02  6.000000e+00  ...  1.000000e+00   0.000000e+00
# max    1.115000e+03  7.000000e+00  ...  1.000000e+00   1.000000e+00
#
# [8 rows x 7 columns]

# %%
sales_train_df['DayOfWeek'].unique()
#1 = segunda-feira
#7 = domingo
# Out:
# array([5, 4, 3, 2, 1, 7, 6])

# %% [markdown]
# ### Dados de Lojas

# %%
assortment = {'a': 'basic', 'b': 'basic', 'c': 'extended'}

# %%
store_info_df = pd.read_csv('/content/store.csv')
print(f'No dataset de vendas, temos informações sobre as {store_info_df.shape[0]} lojas presentes neste dataset de loja')
# Out:
# No dataset de vendas, temos informações sobre as 1115 lojas presentes neste dataset de loja

# %%
store_info_df.tail(10)
# Out:
#       Store StoreType  ... Promo2SinceYear     PromoInterval
# 1105   1106         a  ...          2013.0   Jan,Apr,Jul,Oct
# 1106   1107         a  ...          2010.0   Jan,Apr,Jul,Oct
# 1107   1108         a  ...             NaN               NaN
# 1108   1109         c  ...          2012.0   Jan,Apr,Jul,Oct
# 1109   1110         c  ...             NaN               NaN
# 1110   1111         a  ...          2013.0   Jan,Apr,Jul,Oct
# 1111   1112         c  ...             NaN               NaN
# 1112   1113         a  ...             NaN               NaN
# 1113   1114         a  ...             NaN               NaN
# 1114   1115         d  ...          2012.0  Mar,Jun,Sept,Dec
#
# [10 rows x 10 columns]

# %%
store_info_df.info()
print('Os valores 3, 4, 5, 7, 8, 9 possuem valores nulos')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB
# Os valores 3, 4, 5, 7, 8, 9 possuem valores nulos

# %%
store_info_df.describe()
# Out:
#             Store  CompetitionDistance  ...  Promo2SinceWeek  Promo2SinceYear
# count  1115.00000          1112.000000  ...       571.000000       571.000000
# mean    558.00000          5404.901079  ...        23.595447      2011.763573
# std     322.01708          7663.174720  ...        14.141984         1.674935
# min       1.00000            20.000000  ...         1.000000      2009.000000
# 25%     279.50000           717.500000  ...        13.000000      2011.000000
# 50%     558.00000          2325.000000  ...        22.000000      2012.000000
# 75%     836.50000          6882.500000  ...        37.000000      2013.000000
# max    1115.00000         75860.000000  ...        50.000000      2015.000000
#
# [8 rows x 7 columns]

# %% [markdown]
# ## Exploração de dados

# %% [markdown]
# ### Dados de vendas

# %%
# Verificar dados faltantes na base de dados
print(f'Qtd registros de vendas: {len(sales_train_df)}', end='\n\n')
sns.heatmap(sales_train_df.isnull())
print(sales_train_df.isnull().sum())
# Out:
# Qtd registros de vendas: 1017209
#
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
sales_train_df.drop(sales_train_df.loc[sales_train_df['Date'].isnull()].index, inplace=True)
print(f'Qtd registros de vendas: {len(sales_train_df)}', end='\n\n')
print(sales_train_df.isnull().sum())
# Out:
# Qtd registros de vendas: 1017209
#
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
sales_train_df.hist(bins = 30, figsize = (20, 20), color = 'b')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7feee6dcde10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee68f1190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee68a6790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feee685cd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee68203d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee67d6950>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feee680bf50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee67ce590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee6758710>]],
#       dtype=object)

# %%
closed_train_df = sales_train_df[sales_train_df['Open'] == 0]
open_train_df = sales_train_df[sales_train_df['Open'] == 1]
print(f'Total: {len(sales_train_df) / len(store_info_df)}\nNúmero de lojas/dias fechado: {len(closed_train_df) / len(store_info_df)}\nNúmero de lojas/dias aberto: {len(open_train_df) / len(store_info_df)}\n')
# Out:
# Total: 912.295067264574
# Número de lojas/dias fechado: 154.99282511210762
# Número de lojas/dias aberto: 757.3022421524664

# %%
# Temos que remover a parte da base de dados que contam com registros em que as lojas não abriram, esses dados impactam negativamente nos dados estatísticos
sales_train_df = sales_train_df[sales_train_df['Open'] == 1]
# Vamos remover o campo Open, já que todos os dados são de quando as lojas estavam abertas
sales_train_df.drop(['Open'], axis = 1, inplace = True)
sales_train_df.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# (844392, 8)

# %%
sales_train_df.head()
# Out:
#    Store  DayOfWeek        Date  ...  Promo  StateHoliday  SchoolHoliday
# 0      1          5  2015-07-31  ...      1             0              1
# 1      2          5  2015-07-31  ...      1             0              1
# 2      3          5  2015-07-31  ...      1             0              1
# 3      4          5  2015-07-31  ...      1             0              1
# 4      5          5  2015-07-31  ...      1             0              1
#
# [5 rows x 8 columns]

# %%
# O valor de vendas e clientes aumentaram porque removemos os dados das lojas quando estavam fechadas
sales_train_df.describe()
# Out:
#                Store      DayOfWeek  ...          Promo  SchoolHoliday
# count  844392.000000  844392.000000  ...  844392.000000  844392.000000
# mean      558.422920       3.520361  ...       0.446352       0.193580
# std       321.731914       1.723689  ...       0.497114       0.395103
# min         1.000000       1.000000  ...       0.000000       0.000000
# 25%       280.000000       2.000000  ...       0.000000       0.000000
# 50%       558.000000       3.000000  ...       0.000000       0.000000
# 75%       837.000000       5.000000  ...       1.000000       0.000000
# max      1115.000000       7.000000  ...       1.000000       1.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# ### Dados de lojas

# %%
# Verificar se há valores faltantes
# As barras brancas equivalem os valores nulos
sns.heatmap(store_info_df.isnull(), cbar = False)

# %%
# Se não foi preenchido o mês, não foi preenchido o ano
store_info_df[store_info_df['CompetitionOpenSinceMonth'].isnull()]
# Out:
#       Store StoreType  ... Promo2SinceYear     PromoInterval
# 11       12         a  ...          2010.0   Jan,Apr,Jul,Oct
# 12       13         d  ...          2009.0   Feb,May,Aug,Nov
# 15       16         a  ...             NaN               NaN
# 18       19         a  ...          2011.0  Mar,Jun,Sept,Dec
# 21       22         a  ...          2012.0   Jan,Apr,Jul,Oct
# ...     ...       ...  ...             ...               ...
# 1095   1096         a  ...          2014.0  Mar,Jun,Sept,Dec
# 1099   1100         a  ...          2011.0   Jan,Apr,Jul,Oct
# 1112   1113         a  ...             NaN               NaN
# 1113   1114         a  ...             NaN               NaN
# 1114   1115         d  ...          2012.0  Mar,Jun,Sept,Dec
#
# [354 rows x 10 columns]

# %%
# Quando o Promo2 é zero, então não faz sentido ter os dados de Promo2 posteriores
store_info_df[store_info_df['Promo2SinceWeek'].isnull()]
# Out:
#       Store StoreType  ... Promo2SinceYear  PromoInterval
# 0         1         c  ...             NaN            NaN
# 3         4         c  ...             NaN            NaN
# 4         5         a  ...             NaN            NaN
# 5         6         a  ...             NaN            NaN
# 6         7         a  ...             NaN            NaN
# ...     ...       ...  ...             ...            ...
# 1107   1108         a  ...             NaN            NaN
# 1109   1110         c  ...             NaN            NaN
# 1111   1112         c  ...             NaN            NaN
# 1112   1113         a  ...             NaN            NaN
# 1113   1114         a  ...             NaN            NaN
#
# [544 rows x 10 columns]

# %%
# Convertendo valores nulos em zero
str_cols = ['Promo2SinceWeek', 'Promo2SinceYear', 'PromoInterval', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear']
for col in str_cols:
  store_info_df[col].fillna(0, inplace = True)

# %%
sns.heatmap(store_info_df.isnull(), cbar = False)

# %%
# O CompetitionDistance pode ser tratado inserindo a média de distância presentes no dataset
store_info_df['CompetitionDistance'].fillna(store_info_df['CompetitionDistance'].mean(), inplace = True)

# %%
sns.heatmap(store_info_df.isnull(), cbar = False)

# %%
store_info_df.hist(bins = 30, figsize=(20, 20), color = 'g')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7feee322c390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee323d910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee31e1b90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feee31ac5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee3161bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee3123210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7feee30d8810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee3093890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7feee309da10>]],
#       dtype=object)

# %% [markdown]
# ### Dados unidos (vendas + lojas)
# Vamos trabalhar com os dados unidos, usar um DF para juntar as informações das lojas com as informações das vendas

# %%
# Espécie de JOIN do SQL
sales_all = pd.merge(sales_train_df, store_info_df, how = 'inner', on = 'Store')
sales_all.shape
# Out:
# (844392, 17)

# %%
sales_all.head(10)
# Out:
#    Store  DayOfWeek        Date  ...  Promo2SinceWeek  Promo2SinceYear  PromoInterval
# 0      1          5  2015-07-31  ...              0.0              0.0              0
# 1      1          4  2015-07-30  ...              0.0              0.0              0
# 2      1          3  2015-07-29  ...              0.0              0.0              0
# 3      1          2  2015-07-28  ...              0.0              0.0              0
# 4      1          1  2015-07-27  ...              0.0              0.0              0
# 5      1          6  2015-07-25  ...              0.0              0.0              0
# 6      1          5  2015-07-24  ...              0.0              0.0              0
# 7      1          4  2015-07-23  ...              0.0              0.0              0
# 8      1          3  2015-07-22  ...              0.0              0.0              0
# 9      1          2  2015-07-21  ...              0.0              0.0              0
#
# [10 rows x 17 columns]

# %%
correlations = sales_all.corr()
f, ax = plt.subplots(figsize=(20, 20))
sns.heatmap(correlations, annot = True)

# %% [markdown]
# ## Treinamento do modelo pt1

# %% [markdown]
# ## Treinamento do modelo pt2
